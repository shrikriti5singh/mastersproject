# %%
import pandas as pd

# %%
data = pd.read_excel('thesaurus.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   THE_T_U_UID       209 non-null    float64
#  1   THE_TE_UID        209 non-null    float64
#  2   TERM              209 non-null    object
#  3   CountOfTERM       180 non-null    float64
#  4   BROAD_TERM_U_UID  208 non-null    float64
#  5   BROAD_THE_TE_UID  209 non-null    float64
#  6   BROAD_TERM        209 non-null    object
#  7   TOP_TERM_U_UID    209 non-null    float64
#  8   TOP_THE_TE_UID    209 non-null    float64
#  9   TOP_TERM          209 non-null    object
#  10  Match Getty       209 non-null    object
#  11  Getty URL         209 non-null    object
#  12  Target Concept    209 non-null    object
#  13  Getty BT          209 non-null    object
#  14  Getty BT URL      209 non-null    object
#  15  Getty BT2         197 non-null    object
# ...

# %%
data.describe()
# Out:
#         THE_T_U_UID     THE_TE_UID  CountOfTERM  BROAD_TERM_U_UID  \
# count    209.000000     209.000000   180.000000        208.000000
# mean    7347.124402  502196.578947   166.061111       7030.807692
# std     1149.012475    1037.878946   753.925342         49.846446
# min     6920.000000  501826.000000     1.000000       6933.000000
# 25%     6973.000000  501883.000000     2.000000       7002.000000
# 50%     7026.000000  501937.000000    11.000000       7032.000000
# 75%     7080.000000  501990.000000    43.000000       7065.000000
# max    13418.000000  507964.000000  8757.000000       7107.000000
#
#        BROAD_THE_TE_UID  TOP_TERM_U_UID  TOP_THE_TE_UID
# count        209.000000           209.0           209.0
# mean      501941.679426          7014.0        501925.0
# std           51.321644             0.0             0.0
# min       501841.000000          7014.0        501925.0
# 25%       501913.000000          7014.0        501925.0
# ...

# %%
data.head()
# Out:
#    THE_T_U_UID  THE_TE_UID                      TERM  CountOfTERM  \
# 0          NaN         NaN                       NaN          NaN
# 1       6927.0    501833.0  AUXILIARY FISHING VESSEL          3.0
# 2       6948.0    501854.0                      BUSS         17.0
# 3       6965.0    501873.0                   DRIFTER         82.0
# 4       6993.0    501902.0                    HOOKER          1.0
#
#    BROAD_TERM_U_UID  BROAD_THE_TE_UID      BROAD_TERM  TOP_TERM_U_UID  \
# 0               NaN               NaN             NaN             NaN
# 1            6980.0          501889.0  FISHING VESSEL          7014.0
# 2            6980.0          501889.0  FISHING VESSEL          7014.0
# 3            6980.0          501889.0  FISHING VESSEL          7014.0
# 4            6980.0          501889.0  FISHING VESSEL          7014.0
#
#    TOP_THE_TE_UID        TOP_TERM  Match Getty  \
# 0             NaN             NaN          NaN
# 1        501925.0  MARITIME CRAFT  Broad Match
# ...

# %%
data['BROAD_TERM'].value_counts()
# Out:
# MARITIME CRAFT                   43
# SAILING VESSEL (BY FORM/TYPE)    27
# WARSHIP                          16
# FISHING VESSEL                   11
# BARGE                             9
# SERVICE VESSEL                    7
# DREDGER                           6
# YACHT                             6
# CARGO VESSEL                      6
# NAVAL SUPPORT VESSEL              6
# SHIP OF THE LINE                  6
# SQUARE RIGGED VESSEL              5
# TRAWLER                           5
# SAILING VESSEL (BY RIG)           4
# PASSENGER VESSEL                  3
# SCHOONER                          3
# EAST INDIAMAN                     3
# DRIFTER                           3
# LANDING CRAFT                     2
# HARBOUR SERVICE CRAFT             2
# BRIG                              2
# TUG                               2
# RESCUE VESSEL                     2
# KETCH                             2
# TRANSPORT VESSEL                  2
# LAUNCH                            2
# ...

# %% [markdown]
# Broad term maritime craft is used the most.

# %%
data['TOP_TERM'].unique()
# Out:
# array([nan, 'MARITIME CRAFT'], dtype=object)

# %% [markdown]
# Top term is of no use here. We can delete the column

# %%
data['Match Getty'].value_counts()
# Out:
# Broad Match      66
# Exact match      62
# Broad match      44
# Exact Match      25
# Close Match       5
# Related match     4
# Related Match     1
# Close match       1
# Narrow match      1
# Name: Match Getty, dtype: int64

# %% [markdown]
# Maximum values are broad matched: 110. 87 exact matches.

# %%
data['Target Concept'].unique()
# Out:
# array([nan, 'fishing vessels',
#        '\thookers (inland vessels, <watercraft by location or context>',
#        'trawlers (net fishing vessels, <fishing vessels by function>, ... Furnishings and Equipment (hierarchy name))',
#        'Fishing Vessels', 'Fishing vessels', 'seiners', 'Trawlers',
#        'Whaling Vessels', 'lighters', 'tugboats', 'Tenders',
#        '\tketches (square-rigged vessels)  or \tketches (fore-and-aft-rigged vessels)',
#        'landing craft',
#        'landing craft (<temporary alphabetical list: watercraft>, watercraft, ... Furnishings and Equipment (hierarchy name))',
#        "launches (ships' boats, tenders (utility vessels), ... Furnishings and Equipment",
#        'steam launch', '\tlighters', 'sailing vessels', 'warships',
#        'Boats', 'boats', '\tpatrol boat', 'dredgers', '\tfactory ships',
#        'trawlers', 'cargo vessels', 'factory ships', 'flying boats',
#        'canal barge', '\tlaunchse',
# ...

# %% [markdown]
# Target concept column needs cleaning. But what's the use

# %%
data['Getty BT'].unique()
# Out:
# array([nan, 'hunting and commercial fishing vessels',
#        'sailing vessels by rig type', 'net fishing vessels',
#        '\tnet fishing vessels',
#        '\thunting and commercial fishing vessels', 'cargo vessels',
#        'assistance vessels', 'utility and service vessels',
#        'two-masted square-rigged vessels',
#        'temporary alphabetical list: watercraft', "\tships' boats",
#        '\tcargo vessels', 'naval ships', 'watercraft by general type',
#        'harbor and channel craft', 'merchant vessels by cargo type',
#        'Seaplanes', 'barges', "ships' boats",
#        '\tvehicles (transportation', 'watercraft by method of propulsion',
#        'naval auxiliary ships', 'mechanically powered watercraft',
#        'competition and recreation craft', 'sailing vessels',
#        '\tsquare-ended watercraft', 'fixed-wing aircraft', 'motorboats',
#        'watercraft by function', 'single level rowed watercraft',
# ...
